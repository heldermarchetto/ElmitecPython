# %%
import readUview as ru
import matplotlib
import matplotlib.pyplot as plt
import glob

matplotlib.interactive(True)
matplotlib.use('nbagg')
matplotlib.get_backend()

#eventually check if matplotlib is interactive by printing:
#print('matplotlib is interactive? ',matplotlib.is_interactive())

#substitute the following with a valid file name on your system.
#Notice that in Windows, you should use an r before the quotation marks:
filename = r'K:\Data\TurningPointResolution\50um_FL_High.dat'

ruObj = ru.readUviewClass()
img = ruObj.getImage(filename)
plt.imshow(img, cmap=plt.cm.gray)
# Out:
# <img src="data:image/png;base64,..." width="813.6842207367072">

# %% [markdown]
# Lets now have a look at the contents of the data file:

# %%
for p in ruObj.paramList:
    print(p)
# Out:
# {'number': 107, 'name': 'COL', 'units': 'mBar', 'value': 5.849000173085983e-10}
# {'number': 47, 'name': 'ApertureX', 'units': 'none', 'value': 4000.0}
# {'number': 56, 'name': 'ApertureY', 'units': 'none', 'value': 0.0}
# {'number': 41, 'name': 'Bomb. Voltage', 'units': 'V', 'value': 99999.8984375}
# {'number': 104, 'name': 'Camera exposure (average off)', 'units': 'seconds', 'value': 1.0}
# {'number': 8, 'name': 'CL2 Align. X', 'units': 'mA', 'value': -9.300010681152344}
# {'number': 9, 'name': 'CL2 Align. Y', 'units': 'mA', 'value': 30.279996871948242}
# {'number': 5, 'name': 'CL3 Align. X', 'units': 'mA', 'value': 243.49998474121094}
# {'number': 6, 'name': 'CL3 Align. Y', 'units': 'mA', 'value': -250.0}
# {'number': 10, 'name': 'Cond. Lens 1', 'units': 'mA', 'value': 827.0999755859375}
# {'number': 7, 'name': 'Cond. Lens 2', 'units': 'mA', 'value': 2585.0}
# {'number': 4, 'name': 'Cond. Lens 3', 'units': 'mA', 'value': 778.9000244140625}
# ...

# %% [markdown]
# Lets now find a specific parameter:

# %%
import re
for p in ruObj.paramList:
    if re.search('start', p['name'], re.IGNORECASE):
        print('Start Voltage = %0.2f %s' %(p['value'],p['units']))
# Out:
# Start Voltage = 1.85 V
